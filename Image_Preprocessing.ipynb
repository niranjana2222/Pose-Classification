# %% [markdown]
# <a href="https://colab.research.google.com/github/niranjana2222/Pose-Classification/blob/main/Image_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q opencv-python

# %%
import csv #to handle csv files
import cv2 
import itertools #to handle iterators?
import numpy as np
import pandas as pd 
import tempfile #create directories
import tqdm #progress bars
import sys #create file paths
import os #handle file paths

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection #plot multiple lines on a figure

import tensorflow as tf
import tensorflow_hub as hub #to download pre-trained model (MoveNet Thunder)
from tensorflow import keras #for model layers

# %%
#download pretrained MoveNet model from github
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git

pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 21842, done.
# remote: Counting objects: 100% (502/502), done.
# remote: Compressing objects: 100% (319/319), done.
# remote: Total 21842 (delta 185), reused 376 (delta 117), pack-reused 21340
# Receiving objects: 100% (21842/21842), 37.26 MiB | 32.01 MiB/s, done.
# Resolving deltas: 100% (11943/11943), done.

# %%
import cv2 as cv2
from google.colab.patches import cv2_imshow
#import utils

#download image
original_image = cv2.imread('/content/sample_data/1.jpg', cv2.IMREAD_UNCHANGED)
print("Original Dimension: ", original_image.shape)

#scale = .50
#width = int(original_image.shape[1]*scale)
#height = int(original_image.shape[0]*scale)
#crop = original_image[50:180, 100:300] 
new_dim = (100, 100)
resized_image = cv2.resize(original_image, new_dim, interpolation=cv2.INTER_AREA)

#image_np = utils.visualize(original_image)
#resized_image = utils.keep_aspect_ratio_resizer(image_np, (512, 512))
print("Resized Dimension: ", resized_image.shape) 

print("\nOriginal Image: ")
cv2_imshow(original_image)
print("\nResized Image: ")
cv2_imshow(resized_image)
# Out:
# Original Dimension:  (100, 150, 3)
# Resized Dimension:  (100, 100, 3)
#
# Original Image:
# <PIL.Image.Image image mode=RGB size=150x100 at 0x7F4740079BD0>
# Resized Image:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F4740079910>
